# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()

# %%
# row 1: 5 squares - ending square
G.add_nodes_from(['Kawachiya','Hirasei','Sanno matsuri','Yaozen','Ebiya'])
G.add_node('Kawachiya', location='1A')
G.add_node('Hirasei', location='1B')
G.add_node('Yaozen', location='1E')
G.add_node('Ebiya', location='1F')
G.add_node('Sanno matsuri', location='Ending')

# %%
# row 2: 4 squares
G.add_nodes_from(['Hikeshi','Hyakusekiro','Tokiwa','Ogiya'])
G.add_node('Hikeshi', location='2A')
G.add_node('Hyakusekiro', location='2B')
G.add_node('Tokiwa', location='2E')
G.add_node('Ogiya', location='2F')

# %%
# row 3: 6 squares
G.add_nodes_from(['Kinbaro','Tagawaya','Daishichi','Musashiya','Kokuran','Sakuramochi'])
G.add_node('Kinbaro', location='3A')
G.add_node('Tagawaya', location='3B')
G.add_node('Daishichi', location='3C')
G.add_node('Musashiya', location='3D')
G.add_node('Kokuran', location='3E')
G.add_node('Sakuramochi', location='3F')

# %%
# row 4: 6 squares
G.add_nodes_from(['Matsuganeya','Kinryuzan','Fukagawaya','Ebitsuru','Jubako','Umegawa'])
G.add_node('Matsuganeya', location='4A')
G.add_node('Kinryuzan', location='4B')
G.add_node('Fukagawaya', location='4C')
G.add_node('Ebitsuru', location='4D')
G.add_node('Jubako', location='4E')
G.add_node('Umegawa', location='4F')

# %%
# row 5: 6 squares
G.add_nodes_from(['Daikokuya','Matsusushi','Nodatai','Okamoto','Yanagawa','Gannabe'])
G.add_node('Daikokuya', location='5A')
G.add_node('Matsusushi', location='5B')
G.add_node('Nodatai', location='5C')
G.add_node('Okamoto', location='5D')
G.add_node('Yanagawa', location='5E')
G.add_node('Gannabe', location='5F')

# %%
# row 6: 6 squares
G.add_nodes_from(['Nanaura','Suzuki','Okinaya','Gion','Torikai','Mankyu'])
G.add_node('Nanaura', location='6A')
G.add_node('Suzuki', location='6B')
G.add_node('Okinaya', location='6C')
G.add_node('Gion', location='6D')
G.add_node('Torikai', location='6E')
G.add_node('Mankyu', location='6F')

# %%
# row 7: 6 squares
G.add_nodes_from(['Tateba','Takisoba','Inakashiruko','Kinpura','Myogaya','Yamamoto'])
G.add_node('Tateba', location='7A')
G.add_node('Takisoba', location='7B')
G.add_node('Inakashiruko', location='7C')
G.add_node('Kinpura', location='7D')
G.add_node('Myogaya', location='7E')
G.add_node('Yamamoto', location='7F')

# %%
# row 8: 6 squares
G.add_nodes_from(['Yabusoba','Eitai dango','Yoshiwara','Unagimeshi','Dozeu','Hiraiwa'])
G.add_node('Yabusoba', location='8A')
G.add_node('Eitai dango', location='8B')
G.add_node('Yoshiwara', location='8C')
G.add_node('Unagimeshi', location='8D')
G.add_node('Dozeu', location='8E')
G.add_node('Hiraiwa', location='8F')

# %%
# row 9: 6 squares
G.add_nodes_from(['Kame no senbei','Awayuki','Ikunoya','Mikaeri','Imosakeya','Toshimaya'])
G.add_node('Kame no senbei', location='9A')
G.add_node('Awayuki', location='9B')
G.add_node('Ikunoya', location='9C')
G.add_node('Mikaeri', location='9D')
G.add_node('Imosakeya', location='9E')
G.add_node('Toshimaya', location='9F')

# %%
# row 10: 6 squares
G.add_nodes_from(['Otetsu','Ranmen','Funaya','Sanbuntei','Anago','Abegawa'])
G.add_node('Otetsu', location='10A')
G.add_node('Ranmen', location='10B')
G.add_node('Funaya', location='10C')
G.add_node('Sanbuntei', location='10D')
G.add_node('Anago', location='10E')
G.add_node('Abegawa', location='10F')

# %%
# row 11: 4 squares
G.add_nodes_from(['Ginzo','Awamochi','Inakazushi','Shigenoji'])
G.add_node('Ginzo', location='11A')
G.add_node('Awamochi', location='11B')
G.add_node('Inakazushi', location='11E')
G.add_node('Shigenoji', location='11F')

# %%
# row 12: 5 squares
G.add_nodes_from(['Amazake','Matsumoto','Nihonbashi','Otaya','Mugimeshi'])
G.add_node('Amazake', location='12A')
G.add_node('Matsumoto', location='12B')
G.add_node('Otaya', location='12E')
G.add_node('Mugimeshi', location='12F')
G.add_node('Nihonbashi', location='Starting')

# %%
G.add_edges_from([(1,2),(1,3)])

# %%
G.number_of_nodes()
# Out:
# 5

# %%
list(G.nodes)
# Out:
# ['Kawachiya', 'Hirasei', 'Sanno matsuri', 'Yaozen', 'Ebiya']

# %%
G.nodes.data()
# Out:
# NodeDataView({'Kawachiya': {'location': '1A'}, 'Hirasei': {'location': '1B'}, 'Sanno matsuri': {'location': 'Ending'}, 'Yaozen': {'location': '1E'}, 'Ebiya': {'location': '1F'}})
